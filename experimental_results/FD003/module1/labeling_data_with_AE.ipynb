# %%
import os
import sys
import math
import json
import time
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import the Modules dir
project_path = "<PATH-TO-REPO>/BiMAEB-UDD-RUL/"
sys.path.insert(0, project_path)

from Modules.Models import AutoEncoder
from experimental_results.functions import (TURBOFAN_FEATURES_LIST, 
                       save_labeled_dataframe,
                       normalize_df, 
                       normalize_df_with_context,
                       get_model_reconstructions, 
                       get_latent_space_df)

from experimental_results.unsupervised_labeling_functions import (label_df, 
                                                                  plot_latent_space,
                                                                  plot_labels_recon_errors_and_threshold, 
                                                                  create_unsupervised_labeled_dataset)

# %%
TURBOFAN_FEATURES_LIST
# Out:
# ['operational_setting_1',
#  'operational_setting_2',
#  'operational_setting_3',
#  'sensor_measurement_1',
#  'sensor_measurement_2',
#  'sensor_measurement_3',
#  'sensor_measurement_4',
#  'sensor_measurement_5',
#  'sensor_measurement_6',
#  'sensor_measurement_7',
#  'sensor_measurement_8',
#  'sensor_measurement_9',
#  'sensor_measurement_10',
#  'sensor_measurement_11',
#  'sensor_measurement_12',
#  'sensor_measurement_13',
#  'sensor_measurement_14',
#  'sensor_measurement_15',
#  'sensor_measurement_16',
#  'sensor_measurement_17',
#  'sensor_measurement_18',
#  'sensor_measurement_19',
#  'sensor_measurement_20',
#  'sensor_measurement_21']

# %% [markdown]
# # Define the number of samples that were defined as normal in the time-series

# %%
normal_op_len = 45
norm_op_len_as_pct = True

dataset = "FD003"
model_type = "AE"
prefix = "Pct" if norm_op_len_as_pct else "Len"


print(f"Normality: {normal_op_len} {prefix}")
# Out:
# Normality: 45 Pct

# %% [markdown]
# # Define Paths and File Names

# %%
model_name = f"normOp{prefix}{normal_op_len}_{model_type}"

# Define path's to data directories.
path_to_training_data_dir = "<PATH-TO-DATA-DIR>/NASA_turbofan_data/train"
path_to_testing_data_dir = "<PATH-TO-DATA-DIR>/NASA_turbofan_data/validation"

# Define CSV file names
csv_file_training = f"{dataset}_train.csv"
csv_file_testing = f"{dataset}_test.csv"

# Define paths
dataset_path_training = os.path.join(path_to_training_data_dir, csv_file_training)
dataset_path_testing = os.path.join(path_to_testing_data_dir, csv_file_testing)

path_to_model_state_dict = f"models/{model_name}_model_state_dict"

print(f"Model Path: {path_to_model_state_dict}")
# Out:
# Model Path: models/normOpPct45_AE_model_state_dict

# %% [markdown]
# # Load the Training and Testing Data. Normalize them too

# %%
print(f"Reading dataset \n{dataset_path_training}\n")
print(f"Reading dataset \n{dataset_path_testing}")

# Read data
df_training_not_normalized = pd.read_csv(dataset_path_training)
df_testing_not_normalized = pd.read_csv(dataset_path_testing)

print("\nNormalizing datasets...\n")
# Normalize Datasets
df_training_normalized = normalize_df(df=df_training_not_normalized, 
                                      model_features=TURBOFAN_FEATURES_LIST)

df_testing_normalized = normalize_df_with_context(df=df_testing_not_normalized, 
                                                  df_context=df_training_not_normalized, 
                                                  model_features=TURBOFAN_FEATURES_LIST)
print("Done!")
# Out:
# Reading dataset
# /Users/rafaeltoche/Documents/School/Research/Rainwaters_Lab/DART-LP2/Condition_Monitoring/data/NASA_turbofan_data/train/FD003_train.csv
#
# Reading dataset
# /Users/rafaeltoche/Documents/School/Research/Rainwaters_Lab/DART-LP2/Condition_Monitoring/data/NASA_turbofan_data/validation/FD003_test.csv
#
# Normalizing datasets...
#
# Done!

# %%
# Define device
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using Device: {}".format(device))
# Out:
# Using Device: cpu

# %% [markdown]
# # Set Model and Data Parameters.
# `window_size` is a variable that tells us how many samples in each sample.
# `latent_size` is a variable that defines the latent space size.

# %%
window_size = 1
latent_size = 16
ts_number_features = len(TURBOFAN_FEATURES_LIST)

print(f"Latent Size: {latent_size}")
print(f"Number ts features: {ts_number_features}")
# Out:
# Latent Size: 16
# Number ts features: 24

# %% [markdown]
# # Load the Trained Model

# %%
model = AutoEncoder(ts_number_features=ts_number_features,
                    latent_size=latent_size,
                    device=device,
                    model_name="",
                    metrics_dir="model")

print(f"Reading model at '{path_to_model_state_dict}'")
model.load_state_dict(torch.load(path_to_model_state_dict, map_location=torch.device(device)))
# Out:
# Reading model at 'models/normOpPct45_AE_model_state_dict'
# <All keys matched successfully>

# %% [markdown]
# # Label Both Training and Testing Data With the Model

# %%
# Label Training Data!
num_contiguous_anomalous_samples = 3
num_stds = 3
df_unsuperivsed_labels_training, unit_thresholds_dict = create_unsupervised_labeled_dataset(
                                                            model=model, 
                                                            df=df_training_normalized, 
                                                            identifier_col="unit", 
                                                            cycle_col="cycle", 
                                                            fault_col="fault",
                                                            features_list=TURBOFAN_FEATURES_LIST,
                                                            normal_op_len=normal_op_len, 
                                                            normal_op_len_as_pct=norm_op_len_as_pct,
                                                            num_contiguous_anomalous_samples=num_contiguous_anomalous_samples,
                                                            num_stds=num_stds)
# Out:
# Unit 1
# 	Training Samples:    117
# 	Normal Samples:      116
# 	Abnormal Samples:    26
#
# Unit 2
# 	Training Samples:    114
# 	Normal Samples:      97
# 	Abnormal Samples:    42
#
# Unit 3
# 	Training Samples:    100
# 	Normal Samples:      82
# 	Abnormal Samples:    40
#
# Unit 4
# 	Training Samples:    123
# 	Normal Samples:      55
# 	Abnormal Samples:    94
#
# Unit 5
# 	Training Samples:    96
# 	Normal Samples:      58
# 	Abnormal Samples:    59
#
# Unit 6
# 	Training Samples:    126
# 	Normal Samples:      86
# 	Abnormal Samples:    66
#
# Unit 7
# 	Training Samples:    191
# 	Normal Samples:      119
# 	Abnormal Samples:    114
#
# Unit 8
# 	Training Samples:    121
# 	Normal Samples:      92
# 	Abnormal Samples:    54
#
# Unit 9
# 	Training Samples:    183
# 	Normal Samples:      117
# 	Abnormal Samples:    106
#
# Unit 10
# 	Training Samples:    217
# 	Normal Samples:      110
# 	Abnormal Samples:    154
#
# Unit 11
# 	Training Samples:    89
# 	Normal Samples:      38
# 	Abnormal Samples:    70
#
# Unit 12
# 	Training Samples:    77
# 	Normal Samples:      70
# 	Abnormal Samples:    23
#
# Unit 13
# 	Training Samples:    84
# 	Normal Samples:      61
# 	Abnormal Samples:    40
#
# Unit 14
# 	Training Samples:    94
# 	Normal Samples:      88
# 	Abnormal Samples:    25
#
# Unit 15
# 	Training Samples:    91
# 	Normal Samples:      56
# 	Abnormal Samples:    55
#
# Unit 16
# 	Training Samples:    155
# 	Normal Samples:      111
# 	Abnormal Samples:    78
#
# Unit 17
# 	Training Samples:    141
# 	Normal Samples:      127
# 	Abnormal Samples:    44
#
# Unit 18
# 	Training Samples:    202
# 	Normal Samples:      64
# 	Abnormal Samples:    181
#
# Unit 19
# 	Training Samples:    104
# 	Normal Samples:      62
# 	Abnormal Samples:    63
#
# Unit 20
# 	Training Samples:    153
# 	Normal Samples:      127
# 	Abnormal Samples:    58
#
# Unit 21
# 	Training Samples:    99
# 	Normal Samples:      83
# 	Abnormal Samples:    38
#
# Unit 22
# 	Training Samples:    87
# 	Normal Samples:      79
# 	Abnormal Samples:    26
#
# Unit 23
# 	Training Samples:    89
# 	Normal Samples:      77
# 	Abnormal Samples:    30
#
# Unit 24
# 	Training Samples:    223
# 	Normal Samples:      177
# 	Abnormal Samples:    94
#
# Unit 25
# 	Training Samples:    87
# 	Normal Samples:      48
# 	Abnormal Samples:    58
#
# Unit 26
# 	Training Samples:    110
# 	Normal Samples:      103
# 	Abnormal Samples:    30
#
# Unit 27
# 	Training Samples:    144
# 	Normal Samples:      129
# 	Abnormal Samples:    47
#
# Unit 28
# 	Training Samples:    90
# 	Normal Samples:      76
# 	Abnormal Samples:    34
#
# Unit 29
# 	Training Samples:    101
# 	Normal Samples:      75
# 	Abnormal Samples:    47
#
# Unit 30
# 	Training Samples:    99
# 	Normal Samples:      59
# 	Abnormal Samples:    60
#
# Unit 31
# 	Training Samples:    83
# 	Normal Samples:      28
# 	Abnormal Samples:    72
#
# Unit 32
# 	Training Samples:    86
# 	Normal Samples:      61
# 	Abnormal Samples:    42
#
# Unit 33
# 	Training Samples:    104
# 	Normal Samples:      49
# 	Abnormal Samples:    78
#
# Unit 34
# 	Training Samples:    207
# 	Normal Samples:      169
# 	Abnormal Samples:    83
#
# Unit 35
# 	Training Samples:    104
# 	Normal Samples:      96
# 	Abnormal Samples:    31
#
# Unit 36
# 	Training Samples:    146
# 	Normal Samples:      132
# 	Abnormal Samples:    46
#
# Unit 37
# 	Training Samples:    146
# 	Normal Samples:      120
# 	Abnormal Samples:    58
#
# Unit 38
# 	Training Samples:    91
# 	Normal Samples:      49
# 	Abnormal Samples:    61
#
# Unit 39
# 	Training Samples:    130
# 	Normal Samples:      115
# 	Abnormal Samples:    43
#
# Unit 40
# 	Training Samples:    85
# 	Normal Samples:      51
# 	Abnormal Samples:    52
#
# Unit 41
# 	Training Samples:    133
# 	Normal Samples:      105
# 	Abnormal Samples:    57
#
# Unit 42
# 	Training Samples:    87
# 	Normal Samples:      73
# 	Abnormal Samples:    33
#
# Unit 43
# 	Training Samples:    145
# 	Normal Samples:      123
# 	Abnormal Samples:    53
#
# Unit 44
# 	Training Samples:    81
# 	Normal Samples:      41
# 	Abnormal Samples:    58
#
# Unit 45
# 	Training Samples:    93
# 	Normal Samples:      79
# 	Abnormal Samples:    33
#
# Unit 46
# 	Training Samples:    92
# 	Normal Samples:      73
# 	Abnormal Samples:    39
#
# Unit 47
# 	Training Samples:    122
# 	Normal Samples:      72
# 	Abnormal Samples:    75
#
# Unit 48
# 	Training Samples:    79
# 	Normal Samples:      56
# 	Abnormal Samples:    39
#
# Unit 49
# 	Training Samples:    116
# 	Normal Samples:      89
# 	Abnormal Samples:    51
#
# Unit 50
# 	Training Samples:    73
# 	Normal Samples:      70
# 	Abnormal Samples:    18
#
# Unit 51
# 	Training Samples:    86
# 	Normal Samples:      64
# 	Abnormal Samples:    40
#
# Unit 52
# 	Training Samples:    100
# 	Normal Samples:      88
# 	Abnormal Samples:    34
#
# Unit 53
# 	Training Samples:    74
# 	Normal Samples:      72
# 	Abnormal Samples:    18
#
# Unit 54
# 	Training Samples:    88
# 	Normal Samples:      50
# 	Abnormal Samples:    56
#
# Unit 55
# 	Training Samples:    237
# 	Normal Samples:      114
# 	Abnormal Samples:    174
#
# Unit 56
# 	Training Samples:    88
# 	Normal Samples:      43
# 	Abnormal Samples:    64
#
# Unit 57
# 	Training Samples:    97
# 	Normal Samples:      51
# 	Abnormal Samples:    67
#
# Unit 58
# 	Training Samples:    81
# 	Normal Samples:      61
# 	Abnormal Samples:    36
#
# Unit 59
# 	Training Samples:    135
# 	Normal Samples:      91
# 	Abnormal Samples:    73
#
# Unit 60
# 	Training Samples:    86
# 	Normal Samples:      81
# 	Abnormal Samples:    23
#
# Unit 61
# 	Training Samples:    90
# 	Normal Samples:      67
# 	Abnormal Samples:    42
#
# Unit 62
# 	Training Samples:    111
# 	Normal Samples:      104
# 	Abnormal Samples:    31
#
# Unit 63
# 	Training Samples:    104
# 	Normal Samples:      100
# 	Abnormal Samples:    27
#
# Unit 64
# 	Training Samples:    88
# 	Normal Samples:      48
# 	Abnormal Samples:    59
#
# Unit 65
# 	Training Samples:    106
# 	Normal Samples:      102
# 	Abnormal Samples:    26
#
# Unit 66
# 	Training Samples:    75
# 	Normal Samples:      67
# 	Abnormal Samples:    23
#
# Unit 67
# 	Training Samples:    119
# 	Normal Samples:      93
# 	Abnormal Samples:    51
#
# Unit 68
# 	Training Samples:    91
# 	Normal Samples:      42
# 	Abnormal Samples:    68
#
# Unit 69
# 	Training Samples:    77
# 	Normal Samples:      67
# 	Abnormal Samples:    26
#
# Unit 70
# 	Training Samples:    78
# 	Normal Samples:      75
# 	Abnormal Samples:    19
#
# Unit 71
# 	Training Samples:    185
# 	Normal Samples:      130
# 	Abnormal Samples:    94
#
# Unit 72
# 	Training Samples:    105
# 	Normal Samples:      84
# 	Abnormal Samples:    43
#
# Unit 73
# 	Training Samples:    97
# 	Normal Samples:      89
# 	Abnormal Samples:    29
#
# Unit 74
# 	Training Samples:    87
# 	Normal Samples:      75
# 	Abnormal Samples:    31
#
# Unit 75
# 	Training Samples:    117
# 	Normal Samples:      101
# 	Abnormal Samples:    41
#
# Unit 76
# 	Training Samples:    69
# 	Normal Samples:      12
# 	Abnormal Samples:    72
#
# Unit 77
# 	Training Samples:    115
# 	Normal Samples:      64
# 	Abnormal Samples:    76
#
# Unit 78
# 	Training Samples:    100
# 	Normal Samples:      91
# 	Abnormal Samples:    30
#
# Unit 79
# 	Training Samples:    75
# 	Normal Samples:      70
# 	Abnormal Samples:    21
#
# Unit 80
# 	Training Samples:    67
# 	Normal Samples:      60
# 	Abnormal Samples:    20
#
# Unit 81
# 	Training Samples:    157
# 	Normal Samples:      135
# 	Abnormal Samples:    55
#
# Unit 82
# 	Training Samples:    129
# 	Normal Samples:      17
# 	Abnormal Samples:    139
#
# Unit 83
# 	Training Samples:    82
# 	Normal Samples:      57
# 	Abnormal Samples:    42
#
# Unit 84
# 	Training Samples:    102
# 	Normal Samples:      83
# 	Abnormal Samples:    41
#
# Unit 85
# 	Training Samples:    120
# 	Normal Samples:      86
# 	Abnormal Samples:    60
#
# Unit 86
# 	Training Samples:    154
# 	Normal Samples:      111
# 	Abnormal Samples:    76
#
# Unit 87
# 	Training Samples:    78
# 	Normal Samples:      60
# 	Abnormal Samples:    34
#
# Unit 88
# 	Training Samples:    145
# 	Normal Samples:      107
# 	Abnormal Samples:    70
#
# Unit 89
# 	Training Samples:    94
# 	Normal Samples:      85
# 	Abnormal Samples:    28
#
# Unit 90
# 	Training Samples:    82
# 	Normal Samples:      70
# 	Abnormal Samples:    29
#
# Unit 91
# 	Training Samples:    71
# 	Normal Samples:      66
# 	Abnormal Samples:    19
#
# Unit 92
# 	Training Samples:    72
# 	Normal Samples:      38
# 	Abnormal Samples:    48
#
# Unit 93
# 	Training Samples:    77
# 	Normal Samples:      59
# 	Abnormal Samples:    35
#
# Unit 94
# 	Training Samples:    177
# 	Normal Samples:      90
# 	Abnormal Samples:    125
#
# Unit 95
# 	Training Samples:    75
# 	Normal Samples:      44
# 	Abnormal Samples:    47
#
# Unit 96
# 	Training Samples:    221
# 	Normal Samples:      160
# 	Abnormal Samples:    110
#
# Unit 97
# 	Training Samples:    124
# 	Normal Samples:      100
# 	Abnormal Samples:    51
#
# Unit 98
# 	Training Samples:    139
# 	Normal Samples:      102
# 	Abnormal Samples:    66
#
# Unit 99
# 	Training Samples:    66
# 	Normal Samples:      52
# 	Abnormal Samples:    27
#
# Unit 100
# 	Training Samples:    69
# 	Normal Samples:      56
# 	Abnormal Samples:    27
#
#
# Found 100/100 units with anomalies

# %%
len(df_unsuperivsed_labels_training.query("fault==1")["unit"].unique())
# Out:
# 100

# %%
df_unsupervised_labels_testing = create_unsupervised_labeled_dataset(
                                    model=model, 
                                    df=df_testing_normalized, 
                                    identifier_col="unit", 
                                    cycle_col="cycle", 
                                    fault_col="fault",
                                    features_list=TURBOFAN_FEATURES_LIST,
                                    normal_op_len=0, 
                                    normal_op_len_as_pct=norm_op_len_as_pct,
                                    num_contiguous_anomalous_samples=num_contiguous_anomalous_samples,
                                    num_stds=num_stds, 
                                    unit_thresholds_dict=unit_thresholds_dict)
# Out:
# Unit 1
# 	Training Samples:    0
# 	Normal Samples:      233
# 	Abnormal Samples:    0
#
# Unit 2
# 	Training Samples:    0
# 	Normal Samples:      124
# 	Abnormal Samples:    0
#
# Unit 3
# 	Training Samples:    0
# 	Normal Samples:      208
# 	Abnormal Samples:    26
#
# Unit 4
# 	Training Samples:    0
# 	Normal Samples:      68
# 	Abnormal Samples:    0
#
# Unit 5
# 	Training Samples:    0
# 	Normal Samples:      89
# 	Abnormal Samples:    49
#
# Unit 6
# 	Training Samples:    0
# 	Normal Samples:      64
# 	Abnormal Samples:    0
#
# Unit 7
# 	Training Samples:    0
# 	Normal Samples:      158
# 	Abnormal Samples:    0
#
# Unit 8
# 	Training Samples:    0
# 	Normal Samples:      192
# 	Abnormal Samples:    0
#
# Unit 9
# 	Training Samples:    0
# 	Normal Samples:      238
# 	Abnormal Samples:    0
#
# Unit 10
# 	Training Samples:    0
# 	Normal Samples:      131
# 	Abnormal Samples:    0
#
# Unit 11
# 	Training Samples:    0
# 	Normal Samples:      103
# 	Abnormal Samples:    0
#
# Unit 12
# 	Training Samples:    0
# 	Normal Samples:      146
# 	Abnormal Samples:    0
#
# Unit 13
# 	Training Samples:    0
# 	Normal Samples:      65
# 	Abnormal Samples:    0
#
# Unit 14
# 	Training Samples:    0
# 	Normal Samples:      158
# 	Abnormal Samples:    11
#
# Unit 15
# 	Training Samples:    0
# 	Normal Samples:      112
# 	Abnormal Samples:    0
#
# Unit 16
# 	Training Samples:    0
# 	Normal Samples:      42
# 	Abnormal Samples:    84
#
# Unit 17
# 	Training Samples:    0
# 	Normal Samples:      230
# 	Abnormal Samples:    0
#
# Unit 18
# 	Training Samples:    0
# 	Normal Samples:      51
# 	Abnormal Samples:    193
#
# Unit 19
# 	Training Samples:    0
# 	Normal Samples:      115
# 	Abnormal Samples:    0
#
# Unit 20
# 	Training Samples:    0
# 	Normal Samples:      207
# 	Abnormal Samples:    0
#
# Unit 21
# 	Training Samples:    0
# 	Normal Samples:      245
# 	Abnormal Samples:    18
#
# Unit 22
# 	Training Samples:    0
# 	Normal Samples:      39
# 	Abnormal Samples:    80
#
# Unit 23
# 	Training Samples:    0
# 	Normal Samples:      396
# 	Abnormal Samples:    9
#
# Unit 24
# 	Training Samples:    0
# 	Normal Samples:      266
# 	Abnormal Samples:    209
#
# Unit 25
# 	Training Samples:    0
# 	Normal Samples:      145
# 	Abnormal Samples:    24
#
# Unit 26
# 	Training Samples:    0
# 	Normal Samples:      122
# 	Abnormal Samples:    8
#
# Unit 27
# 	Training Samples:    0
# 	Normal Samples:      104
# 	Abnormal Samples:    0
#
# Unit 28
# 	Training Samples:    0
# 	Normal Samples:      70
# 	Abnormal Samples:    0
#
# Unit 29
# 	Training Samples:    0
# 	Normal Samples:      89
# 	Abnormal Samples:    0
#
# Unit 30
# 	Training Samples:    0
# 	Normal Samples:      274
# 	Abnormal Samples:    59
#
# Unit 31
# 	Training Samples:    0
# 	Normal Samples:      152
# 	Abnormal Samples:    0
#
# Unit 32
# 	Training Samples:    0
# 	Normal Samples:      120
# 	Abnormal Samples:    0
#
# Unit 33
# 	Training Samples:    0
# 	Normal Samples:      4
# 	Abnormal Samples:    176
#
# Unit 34
# 	Training Samples:    0
# 	Normal Samples:      105
# 	Abnormal Samples:    0
#
# Unit 35
# 	Training Samples:    0
# 	Normal Samples:      144
# 	Abnormal Samples:    0
#
# Unit 36
# 	Training Samples:    0
# 	Normal Samples:      90
# 	Abnormal Samples:    0
#
# Unit 37
# 	Training Samples:    0
# 	Normal Samples:      47
# 	Abnormal Samples:    0
#
# Unit 38
# 	Training Samples:    0
# 	Normal Samples:      133
# 	Abnormal Samples:    0
#
# Unit 39
# 	Training Samples:    0
# 	Normal Samples:      266
# 	Abnormal Samples:    44
#
# Unit 40
# 	Training Samples:    0
# 	Normal Samples:      285
# 	Abnormal Samples:    28
#
# Unit 41
# 	Training Samples:    0
# 	Normal Samples:      101
# 	Abnormal Samples:    0
#
# Unit 42
# 	Training Samples:    0
# 	Normal Samples:      87
# 	Abnormal Samples:    0
#
# Unit 43
# 	Training Samples:    0
# 	Normal Samples:      133
# 	Abnormal Samples:    0
#
# Unit 44
# 	Training Samples:    0
# 	Normal Samples:      146
# 	Abnormal Samples:    0
#
# Unit 45
# 	Training Samples:    0
# 	Normal Samples:      88
# 	Abnormal Samples:    0
#
# Unit 46
# 	Training Samples:    0
# 	Normal Samples:      153
# 	Abnormal Samples:    27
#
# Unit 47
# 	Training Samples:    0
# 	Normal Samples:      56
# 	Abnormal Samples:    0
#
# Unit 48
# 	Training Samples:    0
# 	Normal Samples:      158
# 	Abnormal Samples:    21
#
# Unit 49
# 	Training Samples:    0
# 	Normal Samples:      48
# 	Abnormal Samples:    163
#
# Unit 50
# 	Training Samples:    0
# 	Normal Samples:      99
# 	Abnormal Samples:    48
#
# Unit 51
# 	Training Samples:    0
# 	Normal Samples:      118
# 	Abnormal Samples:    0
#
# Unit 52
# 	Training Samples:    0
# 	Normal Samples:      38
# 	Abnormal Samples:    0
#
# Unit 53
# 	Training Samples:    0
# 	Normal Samples:      108
# 	Abnormal Samples:    0
#
# Unit 54
# 	Training Samples:    0
# 	Normal Samples:      50
# 	Abnormal Samples:    0
#
# Unit 55
# 	Training Samples:    0
# 	Normal Samples:      203
# 	Abnormal Samples:    0
#
# Unit 56
# 	Training Samples:    0
# 	Normal Samples:      162
# 	Abnormal Samples:    0
#
# Unit 57
# 	Training Samples:    0
# 	Normal Samples:      158
# 	Abnormal Samples:    0
#
# Unit 58
# 	Training Samples:    0
# 	Normal Samples:      119
# 	Abnormal Samples:    0
#
# Unit 59
# 	Training Samples:    0
# 	Normal Samples:      149
# 	Abnormal Samples:    0
#
# Unit 60
# 	Training Samples:    0
# 	Normal Samples:      112
# 	Abnormal Samples:    0
#
# Unit 61
# 	Training Samples:    0
# 	Normal Samples:      78
# 	Abnormal Samples:    0
#
# Unit 62
# 	Training Samples:    0
# 	Normal Samples:      224
# 	Abnormal Samples:    0
#
# Unit 63
# 	Training Samples:    0
# 	Normal Samples:      137
# 	Abnormal Samples:    0
#
# Unit 64
# 	Training Samples:    0
# 	Normal Samples:      170
# 	Abnormal Samples:    101
#
# Unit 65
# 	Training Samples:    0
# 	Normal Samples:      79
# 	Abnormal Samples:    0
#
# Unit 66
# 	Training Samples:    0
# 	Normal Samples:      122
# 	Abnormal Samples:    0
#
# Unit 67
# 	Training Samples:    0
# 	Normal Samples:      186
# 	Abnormal Samples:    0
#
# Unit 68
# 	Training Samples:    0
# 	Normal Samples:      188
# 	Abnormal Samples:    0
#
# Unit 69
# 	Training Samples:    0
# 	Normal Samples:      105
# 	Abnormal Samples:    0
#
# Unit 70
# 	Training Samples:    0
# 	Normal Samples:      84
# 	Abnormal Samples:    0
#
# Unit 71
# 	Training Samples:    0
# 	Normal Samples:      322
# 	Abnormal Samples:    45
#
# Unit 72
# 	Training Samples:    0
# 	Normal Samples:      232
# 	Abnormal Samples:    0
#
# Unit 73
# 	Training Samples:    0
# 	Normal Samples:      109
# 	Abnormal Samples:    0
#
# Unit 74
# 	Training Samples:    0
# 	Normal Samples:      68
# 	Abnormal Samples:    0
#
# Unit 75
# 	Training Samples:    0
# 	Normal Samples:      191
# 	Abnormal Samples:    0
#
# Unit 76
# 	Training Samples:    0
# 	Normal Samples:      172
# 	Abnormal Samples:    8
#
# Unit 77
# 	Training Samples:    0
# 	Normal Samples:      381
# 	Abnormal Samples:    0
#
# Unit 78
# 	Training Samples:    0
# 	Normal Samples:      224
# 	Abnormal Samples:    55
#
# Unit 79
# 	Training Samples:    0
# 	Normal Samples:      150
# 	Abnormal Samples:    20
#
# Unit 80
# 	Training Samples:    0
# 	Normal Samples:      85
# 	Abnormal Samples:    0
#
# Unit 81
# 	Training Samples:    0
# 	Normal Samples:      142
# 	Abnormal Samples:    13
#
# Unit 82
# 	Training Samples:    0
# 	Normal Samples:      163
# 	Abnormal Samples:    31
#
# Unit 83
# 	Training Samples:    0
# 	Normal Samples:      168
# 	Abnormal Samples:    0
#
# Unit 84
# 	Training Samples:    0
# 	Normal Samples:      76
# 	Abnormal Samples:    0
#
# Unit 85
# 	Training Samples:    0
# 	Normal Samples:      118
# 	Abnormal Samples:    0
#
# Unit 86
# 	Training Samples:    0
# 	Normal Samples:      148
# 	Abnormal Samples:    26
#
# Unit 87
# 	Training Samples:    0
# 	Normal Samples:      218
# 	Abnormal Samples:    0
#
# Unit 88
# 	Training Samples:    0
# 	Normal Samples:      41
# 	Abnormal Samples:    0
#
# Unit 89
# 	Training Samples:    0
# 	Normal Samples:      68
# 	Abnormal Samples:    52
#
# Unit 90
# 	Training Samples:    0
# 	Normal Samples:      187
# 	Abnormal Samples:    19
#
# Unit 91
# 	Training Samples:    0
# 	Normal Samples:      56
# 	Abnormal Samples:    0
#
# Unit 92
# 	Training Samples:    0
# 	Normal Samples:      231
# 	Abnormal Samples:    35
#
# Unit 93
# 	Training Samples:    0
# 	Normal Samples:      158
# 	Abnormal Samples:    0
#
# Unit 94
# 	Training Samples:    0
# 	Normal Samples:      272
# 	Abnormal Samples:    61
#
# Unit 95
# 	Training Samples:    0
# 	Normal Samples:      213
# 	Abnormal Samples:    0
#
# Unit 96
# 	Training Samples:    0
# 	Normal Samples:      352
# 	Abnormal Samples:    6
#
# Unit 97
# 	Training Samples:    0
# 	Normal Samples:      95
# 	Abnormal Samples:    0
#
# Unit 98
# 	Training Samples:    0
# 	Normal Samples:      157
# 	Abnormal Samples:    25
#
# Unit 99
# 	Training Samples:    0
# 	Normal Samples:      254
# 	Abnormal Samples:    35
#
# Unit 100
# 	Training Samples:    0
# 	Normal Samples:      231
# 	Abnormal Samples:    16
#
#
# Found 35/100 units with anomalies

# %% [markdown]
# # Save Data to Their Respective Directories

# %%
# Create the path where to save the DataFrame
file_name_for_labeled_training_data = csv_file_training[:-4] + f"_unsupervised_labels_{model.model_type}_Op{prefix}{normal_op_len}.csv"
save_labeled_dataframe(file_name=file_name_for_labeled_training_data, 
                       save_path=path_to_training_data_dir,
                       df_labeled=df_unsuperivsed_labels_training, 
                       df_unlabeled=df_training_not_normalized)
# Out:
# Saved 'FD003_train_unsupervised_labels_AutoEncoder_OpPct45.csv' to -->
# '/Users/rafaeltoche/Documents/School/Research/Rainwaters_Lab/DART-LP2/Condition_Monitoring/data/NASA_turbofan_data/train'

# %%
file_name_for_labeled_testing_data = csv_file_testing[:-4] + f"_unsupervised_labels_{model.model_type}_Op{prefix}{normal_op_len}.csv"
save_labeled_dataframe(file_name=file_name_for_labeled_testing_data, 
                       save_path=path_to_testing_data_dir,
                       df_labeled=df_unsupervised_labels_testing, 
                       df_unlabeled=df_testing_not_normalized)
# Out:
# Saved 'FD003_test_unsupervised_labels_AutoEncoder_OpPct45.csv' to -->
# '/Users/rafaeltoche/Documents/School/Research/Rainwaters_Lab/DART-LP2/Condition_Monitoring/data/NASA_turbofan_data/validation'

# %%
df_latent_space = get_latent_space_df(model=model, 
                                      df=df_unsuperivsed_labels_training, 
                                      unit_col_identifier_name="unit",
                                      cycle_col="cycle",
                                      features_list=TURBOFAN_FEATURES_LIST)

# %%
plot_latent_space(df_latent_space, title=f"{dataset} Latent Space (p={normal_op_len}%)")

# %% [markdown]
# # Visualize one of the training samples

# %%
unit = 1
title = f"Reconstructions for Engine {unit} in {dataset} Training Data (p={normal_op_len}%)"
unit_threshold = unit_thresholds_dict[str(unit)]
df_unit = df_unsuperivsed_labels_training.query(f"unit=={unit}")
number_normal_samples = math.ceil((normal_op_len / 100) * len(df_unit)) if norm_op_len_as_pct else normal_op_len

plot_labels_recon_errors_and_threshold(model, 
                                       number_normal_samples=number_normal_samples, 
                                       df=df_unit, 
                                       threshold=unit_threshold,
                                       features=TURBOFAN_FEATURES_LIST, 
                                       title=title,
                                       recon_errors_title="Reconstruction Error",
                                       threshold_title=f"Threshold [alpha={unit_threshold:0.6f}]",
                                       x_axis_column="cycle", 
                                       show_zoom_ins=False)

# %% [markdown]
# # Visualize a testing sample

# %%
for unit in df_unsupervised_labels_testing.query("fault==1")["unit"].unique().tolist():
    print(unit)
# Out:
# 3
# 5
# 14
# 16
# 18
# 21
# 22
# 23
# 24
# 25
# 26
# 30
# 33
# 39
# 40
# 46
# 48
# 49
# 50
# 64
# 71
# 76
# 78
# 79
# 81
# 82
# 86
# 89
# 90
# 92
# 94
# 96
# 98
# 99
# 100

# %%
unit = 100
title = f"Reconstructions for Engine {unit} in FD001 Testing Data"
unit_threshold = unit_thresholds_dict[str(unit)]
df_unit = df_unsupervised_labels_testing.query(f"unit=={unit}")
number_normal_samples = math.ceil((normal_op_len / 100) * len(df_unit)) if norm_op_len_as_pct else normal_op_len

plot_labels_recon_errors_and_threshold(model, 
                                       number_normal_samples=0,
                                       df=df_unit, 
                                       threshold=unit_threshold,
                                       features=TURBOFAN_FEATURES_LIST,
                                       title=title,
                                       recon_errors_title="Mean Squared Reconstruction Errors", 
                                       threshold_title=f"MSE Threshold [alpha={unit_threshold:0.6f}]", 
                                       x_axis_column="cycle", 
                                       show_zoom_ins=False)

# %%
ruls = []
cycles = []
for unit in list(df_unsuperivsed_labels_training["unit"].unique()):
    df_unit = df_unsuperivsed_labels_training.query(f"unit=={unit} and fault==1")
    max_rul = df_unit["RUL"].max()
    cycle = df_unit["cycle"].min()
    
    ruls.append(max_rul)
    cycles.append(cycle)

print(f"Smallest Maximum RUL: {min(ruls)}")
print(f"Largets Maximum RUL: {max(ruls)}")
print(f"Average RUL: {np.mean(ruls)}")
print(f"Median RUL: {np.median(ruls)}\n")

print(f"Smallest Cycle: {min(cycles)}")
print(f"Largest Cycle: {max(cycles)}")
print(f"Average Cycle: {np.mean(cycles)}")
print(f"Median Cycle: {np.median(cycles)}")
# print(f"Largest_RUL + Median_RUL = {np.median(ruls) + max(ruls)}")
# Out:
# Smallest Maximum RUL: 17
# Largets Maximum RUL: 180
# Average RUL: 53.21
# Median RUL: 46.0
#
# Smallest Cycle: 82
# Largest Cycle: 401
# Average Cycle: 193.99
# Median Cycle: 178.0

# %%
fault_start_training_data = []
for eng in df_unsuperivsed_labels_training["unit"].unique().tolist():
    df_unit = df_unsuperivsed_labels_training.query(f"unit=={eng} and fault==1")
    if len(df_unit) > 0:
        unit_fault_start = df_unit["cycle"].to_numpy()[0]
        fault_start_training_data.append(unit_fault_start)
    
print(f"Smallest Cycle where a Fault Started: {min(fault_start_training_data)}")
print(f"Largest Cycle where a Fault Started: {max(fault_start_training_data)}")
print(f"Number of samples: {len(fault_start_training_data)}")
sns.histplot(fault_start_training_data)
# Out:
# Smallest Cycle where a Fault Started: 82
# Largest Cycle where a Fault Started: 401
# Number of samples: 100
# <Axes: ylabel='Count'>

# %%
fault_start_testing_data = []
for eng in df_unsupervised_labels_testing["unit"].unique().tolist():
    df_unit = df_unsupervised_labels_testing.query(f"unit=={eng} and fault==1")
    if len(df_unit) > 0:
        unit_fault_start = df_unit["cycle"].to_numpy()[0]
        fault_start_testing_data.append(unit_fault_start)
        
        if unit_fault_start == 1:
            print(f"Unit={eng}")

print(f"Smallest Cycle where a Fault Started: {min(fault_start_testing_data)}")
print(f"Largest Cycle where a Fault Started: {max(fault_start_testing_data)}")
print(f"Number of samples: {len(fault_start_testing_data)}")
sns.histplot(fault_start_testing_data)
# Out:
# Smallest Cycle where a Fault Started: 5
# Largest Cycle where a Fault Started: 397
# Number of samples: 35
# <Axes: ylabel='Count'>
